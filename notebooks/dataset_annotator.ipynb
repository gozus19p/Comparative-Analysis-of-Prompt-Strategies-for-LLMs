# %%
# !pip install spacy pandas
# Out:
# Looking in indexes: http://dev:****@nexus-leitha.servizi.gr-u.it/repository/leitha_python_all/simple
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# !python -m spacy download en_core_web_trf
# Out:
# Looking in indexes: http://dev:****@nexus-leitha.servizi.gr-u.it/repository/leitha_python_all/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 2.0 MB/s eta 0:00:0000:0100:07
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %%
import os.path

import pandas as pd
import spacy

# python -m spacy download en_core_web_trf
_NLP = spacy.load("en_core_web_trf")

# %%
text = "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the fact that it goes where other shows wouldn't dare. Forget pretty pictures painted for mainstream audiences, forget charm, forget romance...OZ doesn't mess around. The first episode I ever saw struck me as so nasty it was surreal, I couldn't say I was ready for it, but as I watched more, I developed a taste for Oz, and got accustomed to the high levels of graphic violence. Not just violence, but injustice (crooked guards who'll be sold out for a nickel, inmates who'll kill on order and get away with it, well mannered, middle class inmates being turned into prison bitches due to their lack of street skills or prison experience) Watching Oz, you may become comfortable with what is uncomfortable viewing....thats if you can get in touch with your darker side."

res = _NLP(text)
res
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
# ...

# %%
import json

imdb: pd.DataFrame = pd.read_csv(
    os.path.abspath(
        os.path.join(
            "..",
            "resources",
            "IMDB Dataset.csv"
        )
    )
)

total_rows: int = len(imdb)
counter: int = 0


def extract_ents_and_labels(row: pd.Series) -> list[dict[str, str]]:
    global total_rows, counter
    counter += 1
    print(f"Extracting ents and labels for {counter} out of {total_rows}")
    return [{"label": ent.label_, "value": ent.text} for ent in _NLP(row["review"]).ents if
            ent.label_ in ["PERSON", "ORG", "LOC"]]


imdb["entities"] = imdb.apply(extract_ents_and_labels, axis=1)
imdb["json"] = imdb.apply(
    lambda x: json.dumps({"review": x["review"], "sentiment": x["sentiment"], "entities": x["entities"]}), axis=1)
imdb.head(n=10)
# Out:
# Extracting ents and labels for 1 out of 50000
# Extracting ents and labels for 2 out of 50000
# Extracting ents and labels for 3 out of 50000
# Extracting ents and labels for 4 out of 50000
# Extracting ents and labels for 5 out of 50000
# Extracting ents and labels for 6 out of 50000
# Extracting ents and labels for 7 out of 50000
# Extracting ents and labels for 8 out of 50000
# Extracting ents and labels for 9 out of 50000
# Extracting ents and labels for 10 out of 50000
# Extracting ents and labels for 11 out of 50000
# Extracting ents and labels for 12 out of 50000
# Extracting ents and labels for 13 out of 50000
# Extracting ents and labels for 14 out of 50000
# Extracting ents and labels for 15 out of 50000
# Extracting ents and labels for 16 out of 50000
# Extracting ents and labels for 17 out of 50000
# Extracting ents and labels for 18 out of 50000
# Extracting ents and labels for 19 out of 50000
# Extracting ents and labels for 20 out of 50000
# ...

# %%
output_path: str = os.path.abspath(
    os.path.join(
        "..",
        "resources",
        "IMDB Dataset Enriched.csv"
    )
)
imdb.to_csv(path_or_buf=output_path, index=False)
